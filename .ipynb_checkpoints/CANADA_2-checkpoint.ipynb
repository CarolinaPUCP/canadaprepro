# %%
# EJERCICIO 1

# %%
# 1. Check if your country is a polygon or multipolygon.

# %%
import os


import geopandas as gpd
from  fiona import listlayers

#mapa
canadamaps='maps/canadaMaps.gpkg'

#layers in maps
listlayers(canadamaps)
# Out:
# ['countries', 'cities', 'rivers']

# %%
canada=gpd.read_file(canadamaps,layer='countries')
canada_cities=gpd.read_file(canadamaps,layer='cities')
canada_rivers=gpd.read_file(canadamaps,layer='rivers')

# %%
canada
# Out:
#   COUNTRY                                           geometry
# 0  Canada  MULTIPOLYGON (((385323.172 23951253.091, 38663...

# %%
# 2. Recover just the boundaries of that country.

# %%
canada.boundary.plot()
# Out:
# <Axes: >

# %%
# 3. Turn the boundary into a GDF

# %%
type(canada.boundary)
# Out:
# geopandas.geoseries.GeoSeries

# %%
canada.boundary.to_frame()
# Out:
#                                                    0
# 0  MULTILINESTRING ((385323.172 23951253.091, 386...

# %%
# conversion
canada_border=canada.boundary.to_frame() 

# new column (optional)
canada_border['name']='Canada' 

# renaming the geometry column
canada_border.rename(columns={0:'geometry'},inplace=True) 

#setting the geometry (the name is not enough)
canada_border = canada_border.set_geometry("geometry")

# verifying:

new_crs = "EPSG:3978"
# Cambia el CRS del GeoDataFrame
canada = canada.to_crs(new_crs)
canada_cities = canada_cities.to_crs(new_crs)
canada_rivers = canada_rivers.to_crs(new_crs)

# Ahora, gdf tiene el nuevo CRS
canada_border.crs
# Out:
# <Projected CRS: EPSG:5641>
# Name: SIRGAS 2000 / Brazil Mercator
# Axis Info [cartesian]:
# - X[east]: Easting (metre)
# - Y[north]: Northing (metre)
# Area of Use:
# - name: Brazil - offshore - equatorial margin.
# - bounds: (-51.64, -5.74, -32.43, 7.04)
# Coordinate Operation:
# - name: Petrobras Mercator
# - method: Mercator (variant B)
# Datum: Sistema de Referencia Geocentrico para las AmericaS 2000
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
canada_border
# Out:
#                                             geometry    name
# 0  MULTILINESTRING ((385323.172 23951253.091, 386...  Canada

# %%
# EJERCICIO 2

# %%
# 1. Look for sub administrative divisions of your country
# 2. Check all the CRSs of those divisions
# 3. If you find one CRS is missing, fill the CRS with the right projection.

# %%
canada.crs.to_epsg()==canada_cities.crs.to_epsg()==canada_rivers.crs.to_epsg()
# Out:
# True

# %%
canada.crs
# Out:
# <Projected CRS: EPSG:3978>
# Name: NAD83 / Canada Atlas Lambert
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.
# - bounds: (-141.01, 38.21, -40.73, 86.46)
# Coordinate Operation:
# - name: Canada Atlas Lambert
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
canada_cities.crs
# Out:
# <Projected CRS: EPSG:3978>
# Name: NAD83 / Canada Atlas Lambert
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.
# - bounds: (-141.01, 38.21, -40.73, 86.46)
# Coordinate Operation:
# - name: Canada Atlas Lambert
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
canada_rivers.crs
# Out:
# <Projected CRS: EPSG:3978>
# Name: NAD83 / Canada Atlas Lambert
# Axis Info [cartesian]:
# - E[east]: Easting (metre)
# - N[north]: Northing (metre)
# Area of Use:
# - name: Canada - onshore and offshore - Alberta; British Columbia; Manitoba; New Brunswick; Newfoundland and Labrador; Northwest Territories; Nova Scotia; Nunavut; Ontario; Prince Edward Island; Quebec; Saskatchewan; Yukon.
# - bounds: (-141.01, 38.21, -40.73, 86.46)
# Coordinate Operation:
# - name: Canada Atlas Lambert
# - method: Lambert Conic Conformal (2SP)
# Datum: North American Datum 1983
# - Ellipsoid: GRS 1980
# - Prime Meridian: Greenwich

# %%
# EJERCICIO 3

# 1. Look for some points in a CSV file about your country.

# 2. Turn those points into a spatial object.

# 3. Save the layer.

# %%
import pandas as pd
import os

info_avion= pd.read_csv(os.path.join("data", "canada_a2.csv"), encoding='latin1')
info_avion
# Out:
#              id        ident                 type  \
# 0     #meta +id  #meta +code  #loc +airport +type
# 1          1990         CYYZ        large_airport
# 2          1941         CYVR        large_airport
# 3          1928         CYUL        large_airport
# 4          1973         CYYC        large_airport
# ...         ...          ...                  ...
# 3076     509083      CA-0872               closed
# 3077     320714      CA-0659               closed
# 3078      39705      CA-0059               closed
# 3079      40067      CA-0421               closed
# 3080      40068      CA-0422               closed
#
#                                                    name   latitude_deg  \
# 0                                   #loc +airport +name      #geo +lat
# 1       Toronto Lester B. Pearson International Airport        43.6772
# 2                       Vancouver International Airport   49.193901062
# 3     Montreal / Pierre Elliott Trudeau Internationa...  45.4706001282
# 4                         Calgary International Airport   51.113899231
# ...                                                 ...            ...
# 3076                                  Cow Creek Airport       42.98434
# 3077                                     Yahk Aerodrome         49.109
# 3078                                    Brazeau Airport      52.967817
# 3079                                    E C Air Airport       51.53614
# 3080                                       Yoyo Airport        58.9258
#
#        longitude_deg         elevation_ft                 continent  \
# 0          #geo +lon  #geo +elevation +ft  #region +continent +code
# 1           -79.6306                  569                       NaN
# 2     -123.183998108                   14                       NaN
# 3     -73.7407989502                  118                       NaN
# 4     -114.019996643                 3557                       NaN
# ...              ...                  ...                       ...
# 3076       -82.20114                  643                       NaN
# 3077       -116.0598                 2870                       NaN
# 3078      -115.86737                  NaN                       NaN
# 3079      -111.19324                  NaN                       NaN
# 3080     -121.473201                 1950                       NaN
#
#         country_name           iso_country  ...              municipality  \
# 0     #country +name  #country +code +iso2  ...  #loc +municipality +name
# 1             Canada                    CA  ...                   Toronto
# 2             Canada                    CA  ...                 Vancouver
# 3             Canada                    CA  ...                 MontrÃ©al
# 4             Canada                    CA  ...                   Calgary
# ...              ...                   ...  ...                       ...
# 3076          Canada                    CA  ...                   Wyoming
# 3077          Canada                    CA  ...                      Yahk
# 3078          Canada                    CA  ...                Yellowhead
# 3079          Canada                    CA  ...                Youngstown
# 3080          Canada                    CA  ...                      Yoyo
#
#        scheduled_service                  gps_code                  iata_code  \
# 0     #status +scheduled  #loc +airport +code +gps  #loc +airport +code +iata
# 1                      1                      CYYZ                        YYZ
# 2                      1                      CYVR                        YVR
# 3                      1                      CYUL                        YUL
# 4                      1                      CYYC                        YYC
# ...                  ...                       ...                        ...
# 3076                   0                       NaN                        NaN
# 3077                   0                       NaN                        NaN
# 3078                   0                       NaN                        NaN
# 3079                   0                       NaN                        NaN
# 3080                   0                       NaN                        NaN
#
#                       local_code                                home_link  \
# 0     #loc +airport +code +local                      #meta +url +airport
# 1                            YYZ                     http://www.gtaa.com/
# 2                            NaN                       http://www.yvr.ca/
# 3                            YUL  http://www.admtl.com/passager/Home.aspx
# 4                            NaN           http://www.calgaryairport.com/
# ...                          ...                                      ...
# 3076                         NaN                                      NaN
# 3077                         NaN                                      NaN
# 3078                         NaN                                      NaN
# 3079                         NaN                                      NaN
# 3080                         NaN                                      NaN
#
#                                          wikipedia_link  \
# 0                                 #meta +url +wikipedia
# 1     https://en.wikipedia.org/wiki/Toronto_Pearson_...
# 2     https://en.wikipedia.org/wiki/Vancouver_Intern...
# 3     https://en.wikipedia.org/wiki/Montr%C3%A9al-Pi...
# 4     https://en.wikipedia.org/wiki/Calgary_Internat...
# ...                                                 ...
# 3076                                                NaN
# 3077                                                NaN
# 3078                                                NaN
# 3079                                                NaN
# 3080                                                NaN
#
#                                         keywords         score  \
# 0                                #meta +keywords  #meta +score
# 1     YTO, Toronto International Airport, Malton       1040275
# 2                                            NaN       1018875
# 3                            YMQ, Dorval Airport         51875
# 4                                   McCall Field         51275
# ...                                          ...           ...
# 3076                                         NaN             0
# 3077                                         NaN             0
# 3078                                         NaN             0
# 3079                                         NaN             0
# 3080                                    BL8, BL8             0
#
#                    last_updated
# 0                #date +updated
# 1     2023-05-11T14:58:13+00:00
# 2     2013-07-22T11:09:16+00:00
# 3     2014-03-16T22:14:44+00:00
# 4     2014-03-18T23:08:53+00:00
# ...                         ...
# 3076  2023-05-25T03:06:48+00:00
# 3077  2022-11-23T12:47:24+00:00
# 3078  2021-02-18T17:19:40+00:00
# 3079  2022-12-03T06:44:57+00:00
# 3080  2016-09-10T06:55:25+00:00
#
# [3081 rows x 23 columns]

# %%
# bye first row 
info_avion.drop(index=0,inplace=True)
info_avion.reset_index(drop=True, inplace=True)

# keep the  columns needed
keep=['name','type','latitude_deg', 'longitude_deg','elevation_ft','region_name','municipality']
info_avion=info_a.loc[:,keep]
info_avion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3080 entries, 0 to 3079
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3080 non-null   object
#  1   type           3080 non-null   object
#  2   latitude_deg   3080 non-null   float64
#  3   longitude_deg  3080 non-null   float64
#  4   elevation_ft   2561 non-null   float64
#  5   region_name    3080 non-null   object
#  6   municipality   2514 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 168.6+ KB

# %%
numericCols=['latitude_deg', 'longitude_deg','elevation_ft']
info_avion[numericCols]=info_a.loc[:,numericCols].apply(lambda x:pd.to_numeric(x))

# now 
info_avion.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3080 entries, 0 to 3079
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   name           3080 non-null   object
#  1   type           3080 non-null   object
#  2   latitude_deg   3080 non-null   float64
#  3   longitude_deg  3080 non-null   float64
#  4   elevation_ft   2561 non-null   float64
#  5   region_name    3080 non-null   object
#  6   municipality   2514 non-null   object
# dtypes: float64(3), object(4)
# memory usage: 168.6+ KB

# %%
# let's plot

base = canada.plot(color='white', edgecolor='black') #unprojected

info_avion.plot.scatter(x = 'longitude_deg', y = 'latitude_deg',ax=base)
# Out:
# <Axes: xlabel='longitude_deg', ylabel='latitude_deg'>

# %%
avion=gpd.GeoDataFrame(data=info_a.copy(),
                 geometry=gpd.points_from_xy(info_avion.longitude_deg,
                                             info_avion.latitude_deg), 
                 crs=3978)# the coordinates were in degrees - unprojected

# %%
avion = avion.to_crs(3978)

# %%
# let's plot

base = canada.plot(color='white', edgecolor='black')
avion.plot(ax=base,markersize=1)
# Out:
# <Axes: >

# %%
# EJERCICIO 4

# Compute the centroid of your country.

# Combine all the polygons to the north, and also all the polygons to the south; use unary union.

# Detect the amount of duplicates after the combination.

# Plot both maps so that duplicates appear.

# %%
centroCanada=canada.centroid
centroCanada
# Out:
# 0    POINT (-60310.404 1250285.721)
# dtype: geometry

# %%
type(centroCanada.x[0]),type(centroCanada.y[0])
# Out:
# (numpy.float64, numpy.float64)

# %%
canada_states=gpd.read_file(os.path.join("maps","gpr_000b11a_e","gpr_000b11a_e.shp"))

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots(figsize=(12, 12))

canada_states.plot(ax=ax, facecolor='lightgrey', edgecolor='black', linewidth=0.2)

plt.show()

# %%
import matplotlib.pyplot as plt
import geopandas as gpd


fig, axs = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False, figsize=(8, 8))

centroidX = centroCanada.x[0]
centroidY = centroCanada.y[0]

axs[0, 0].set_title('LeftOf_Centroid, Above_Centroid', fontsize=5)
canada_states.cx[:centroidX, centroidY:].plot(ax=axs[0, 0])

axs[0, 1].set_title('RightOf_Centroid, Above_Centroid', fontsize=5)
brazil_states.cx[centroidX:, centroidY:].plot(ax=axs[0, 1])

axs[1, 0].set_title('LeftOf_Centroid, Below_Centroid', fontsize=5)
brazil_states.cx[:centroidX, :centroidY].plot(ax=axs[1, 0])

axs[1, 1].set_title('RightOf_Centroid, Below_Centroid', fontsize=5)
brazil_states.cx[centroidX:, :centroidY].plot(ax=axs[1, 1])

# Establecer el aspecto explícitamente como 'equal'
for ax in axs.flat:
    ax.set_aspect('equal')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[96], line 14
#      11 centroidY = centroCanada.y[0]
#      13 axs[0, 0].set_title('LeftOf_Centroid, Above_Centroid', fontsize=5)
# ---> 14 canada_states.cx[:centroidX, centroidY:].plot(ax=axs[0, 0])
#      16 axs[0, 1].set_title('RightOf_Centroid, Above_Centroid', fontsize=5)
#      17 brazil_states.cx[centroidX:, centroidY:].plot(ax=axs[0, 1])
#
# File ~\anaconda3\Lib\site-packages\geopandas\plotting.py:979, in GeoplotAccessor.__call__(self, *args, **kwargs)
#     977 kind = kwargs.pop("kind", "geo")
#     978 if kind == "geo":
# --> 979     return plot_dataframe(data, *args, **kwargs)
#     980 if kind in self._pandas_kinds:
#     981     # Access pandas plots
#     982     return PlotAccessor(data)(kind=kind, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\geopandas\plotting.py:690, in plot_dataframe(df, column, cmap, color, ax, cax, categorical, legend, scheme, k, vmin, vmax, markersize, figsize, legend_kwds, categories, classification_kwds, missing_kwds, aspect, **style_kwds)
#     688     bounds = df.total_bounds
#     689     y_coord = np.mean([bounds[1], bounds[3]])
# --> 690     ax.set_aspect(1 / np.cos(y_coord * np.pi / 180))
#     691     # formula ported from R package sp
#     692     # https://github.com/edzer/sp/blob/master/R/mapasp.R
#     693 else:
#     694     ax.set_aspect("equal")
#
# File ~\anaconda3\Lib\site-packages\matplotlib\axes\_base.py:1669, in _AxesBase.set_aspect(self, aspect, adjustable, anchor, share)
#    1667     aspect = float(aspect)  # raise ValueError if necessary
#    1668     if aspect <= 0 or not np.isfinite(aspect):
# -> 1669         raise ValueError("aspect must be finite and positive ")
#    1671 if share:
#    1672     axes = {sibling for name in self._axis_names
#    1673             for sibling in self._shared_axes[name].get_siblings(self)}
#
# ValueError: aspect must be finite and positive

# %%
# EJERCICIO 5

# Select some points from your maps.

# Create the convex hull for those points.

# Turn the hull into a GDF.

# Plot the hull on top of the country.

# %%
# para ver que tipos de aeropuestos hay

avion['type'].value_counts()
# Out:
# type
# small_airport     1080
# closed             773
# heliport           476
# seaplane_base      408
# medium_airport     329
# large_airport       13
# balloonport          1
# Name: count, dtype: int64

# %%
# otro nombre para columnas

avion.rename(columns={'type':'kind'},inplace=True)

# %%
canada_AirTopLeft=avion[avion.kind=='small_airport'].cx[:centroidX,centroidY:]
canada_AirTopRight=avion[avion.kind=='small_airport'].cx[centroidX:,centroidY:]
canada_AirBottomLeft=avion[avion.kind=='small_airport'].cx[:centroidX,:centroidY]
canada_AirBottomRight=avion[avion.kind=='small_airport'].cx[centroidX:,:centroidY]

# %%
base=canada_AirTopLeft.plot(facecolor='grey', alpha=0.4)
canada_AirTopRight.plot(ax=base,facecolor='orange', alpha=0.4)
canada_AirBottomLeft.plot(ax=base,facecolor='green', alpha=0.4)
canada_AirBottomRight.plot(ax=base,facecolor='red', alpha=0.4)
# Out:
# C:\Users\cpauc\AppData\Local\Temp\ipykernel_19928\1774712452.py:1: UserWarning: The GeoDataFrame you are attempting to plot is empty. Nothing has been displayed.
#   base=canada_AirTopLeft.plot(facecolor='grey', alpha=0.4)
# <Axes: >
